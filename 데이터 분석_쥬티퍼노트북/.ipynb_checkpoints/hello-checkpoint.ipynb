# %%
print("hello world")
# Out:
# hello world

# %%
print("hello")
print(10+20)    

a = 10    #변수 선언과 값 저장    
b = 20
c = a + b
print(c)
# Out:
# hello
# 30

# %% [markdown]
# ### 리스트 생성과 관리

# %%
flower = ["벚꽃", "개나리", "진달래"]
print(flower)
flower[0]
flower[-1]
# Out:
# ['벚꽃', '개나리', '진달래']
# '진달래'

# %% [markdown]
# #### 딕셔너리 생성과 관리

# %%
user = {
    "name": "우영우", 
    "age": 30
}
print(user)
print(user["name"])
print(user["age"])
user["city"] = "서울"
print(user)
# Out:
# {'name': '우영우', 'age': 30}
# 우영우
# 30
# {'name': '우영우', 'age': 30, 'city': '서울'}
